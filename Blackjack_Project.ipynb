# %% [markdown]
# ## Python Blackjack
# For this project you will make a Blackjack game using Python. Click <a href="">here</a> to familiarize yourself with the the rules of the game. You won't be implementing every rule "down to the letter" with the game, but we will doing a simpler version of the game. This assignment will be given to further test your knowledge on object-oriented programming concepts.
# ### Rules:
# `1. ` The game will have two players: the Dealer and the Player. The game will start off with a deck of 52 cards. The 52 cards will consist of 4 different suits: Clubs, Diamonds, Hearts and Spades. For each suit, there will be cards numbered 1 through 13. <br>
#
# **Note: No wildcards will be used in the program**
#
# `2. ` When the game begins, the dealer will shuffle the deck of cards, making them randomized. After the dealer shuffles, it will deal the player 2 cards and will deal itself 2 cards from. The Player should be able to see both of their own cards, but should only be able to see one of the Dealer's cards.
#
# `3. ` The objective of the game is for the Player to count their cards after they're dealt. If they're not satisfied with the number, they have the ability to 'Hit'. A hit allows the dealer to deal the Player one additional card. The Player can hit as many times as they'd like as long as they don't 'Bust'. A bust is when the Player is dealt cards that total more than 21.
#
# `4. ` If the dealer deals the Player cards equal to 21 on the **first** deal, the Player wins. This is referred to as Blackjack. Blackjack is **NOT** the same as getting cards that equal up to 21 after the first deal. Blackjack can only be attained on the first deal.
#
# `5. ` The Player will never see the Dealer's hand until the Player chooses to 'stand'. A Stand is when the player tells the dealer to not deal it anymore cards. Once the player chooses to Stand, the Player and the Dealer will compare their hands. Whoever has the higher number wins. Keep in mind that the Dealer can also bust.
#
# ***This will be an exercise of how well you understand OOP(Object Oriented Programming). That said, though each of you will need to submit your own file to the classroom link - all of you can and should treat your collective knowledge as a think tank. Meaning, if one of you understands a concept or portion of the project please feel free to submit that to the group. Also, feel free to send that helpful information to the slack channel for those who may be away.***

# %% [markdown]
# # Instructor Feedback
#
# Nice work on the project! There are a few things I saw that I want to point out though.
#
# 1. Inside of your `Deck` class the `cards()` method has a `for loop` that has the key word `type` in it. I understand what you were doing there, but a choice there would be `c_type` because again, `type` itself is a keyword in python. That could have caused problems but luckily in this case it did not. Becareful with that in the future though.
#
# 2. Inside of your `main()` function you have `start()` and `gaming`. Again, though this works, a cleaner approach would be to seperate these out into different function definitions (pretty much just keeping what you have and moving it outside of the `main()`) and then call those functions like this:
#     ```python
#       def main():
#         start()
#         gaming()
#     ```
#
# Other than that, good work.

# %%
import random
from IPython.display import clear_output

class Deck:
    def __init__(self, deck_of_cards):
        self.deck_of_cards = deck_of_cards

    def cards(self):
        self.deck_of_cards = []
        card_types = ["spades", "hearts", "diamonds", "clubs"]
        for type in card_types:
            for i in range(1, 14):
                self.deck_of_cards.append((type, i))


    def shuffle(self):
        random.shuffle(self.deck_of_cards)

    def add_card(self):
        return self.deck_of_cards.pop(0)




class Human():

    def __init__(self, name, cards, score):
        self.name = name
        self.cards = cards
        self.score = score
        self.bet = 0

    def print_info(self):
        print("{} got cards : {}. Total score is {}".format(self.name,self.cards, self.score))

    def sum(self):
        sum = 0
        for card in self.cards:
            sum = sum + card[1]
        return sum

    def check_sum(self):
        sum = 0
        for card in self.cards:
            sum = sum + card[1]
        if sum > 21:
            return True
        else:
            return False



class Player(Human):

    def __init__(self, name, cards, score):
        super().__init__(name, cards, score)

    def list_cards(self):
        for card in self.cards:
            print(card[0], card[1])


class Dealer(Human):

    def __init__(self,name, cards, score):
        super().__init__(name, cards, score)
    def list_cards(self):
        for i in range(len(self.cards) - 1):
            card = self.cards[i]
            print(card[0], card[1])
        print("hiden card")

    def show_cards(self):
        for i in range(len(self.cards)):
            card = self.cards[i]
            print(card[0], card[1])


class Game():
    pass


def main():


    def start():
        while True:
            player1.cards = []
            dealer1.cards = []
            player1.bet = int(input("what the bet? : "))
            clear_output()
            for i in range(2):
                player1.cards.append(game.add_card())  # add card for player
                dealer1.cards.append(game.add_card())  # add card for dealer
            print("{} has a {} points".format(player1.name, player1.score))
            player1.list_cards()
            if player1.check_sum():
                dealer1.score += player1.bet
                print("You Lose")
                break

            while dealer1.sum() < 17:
                dealer1.cards.append(game.add_card())  # add card for dealer if needed
            print("{} has a {} points".format(dealer1.name,dealer1.score))
            dealer1.list_cards()   
            gaming()

    def gaming():


        while True:
           
            answer = input ("if you want a hit. Enter: Hit; if yo want to stand. Enter: stand :") # ask what's next
            if answer.lower() == "hit":
                clear_output()
                player1.cards.append(game.add_card()) #adding card for player if needed
                if player1.check_sum(): #check if sum of ypur cards more than 21                    
                    dealer1.score += player1.bet
                    print("{} has a {} points".format(player1.name, player1.score))
                    player1.list_cards()
                    print("{} has a {} points".format(dealer1.name,dealer1.score))
                    dealer1.list_cards()    
                    print ("You lose!")
                    break
                print("{} has a {} points".format(player1.name, player1.score))
                player1.list_cards()
                print("{} has a {} points".format(dealer1.name,dealer1.score))
                dealer1.list_cards()    
                

            elif answer.lower() == "stand":
                clear_output()
                if dealer1.check_sum():                  
                    player1.score +=player1.bet
                    print("{} has a {} points".format(player1.name, player1.score))
                    player1.list_cards()
                    print("{} has a {} points".format(dealer1.name,dealer1.score))
                    dealer1.show_cards()
                    print ("You win! ")
                    break
                else:
                    dealer1.show_cards()
                    if player1.sum() > dealer1.sum():                       
                        player1.score += player1.bet
                        print("{} has a {} points".format(player1.name, player1.score))
                        player1.list_cards()
                        print("{} has a {} points".format(dealer1.name,dealer1.score))
                        dealer1.show_cards()
                        print("You win! ")

                    elif dealer1.sum() > player1.sum():                     
                        dealer1.score +=player1.bet
                        print("{} has a {} points".format(player1.name, player1.score))
                        player1.list_cards()
                        print("{} has a {} points".format(dealer1.name,dealer1.score))
                        dealer1.show_cards()
                        print("You lose! ")
 
                    else:                      
                        print("{} has a {} points".format(player1.name, player1.score))
                        player1.list_cards()
                        print("{} has a {} points".format(dealer1.name,dealer1.score))
                        dealer1.show_cards()
                        print("Nobody win")
                    break
            else:
                print("Wrong input")

    player1 = Player(input("Enter your name: "), [], 0) # inicialize player
    clear_output()
    dealer1 = Dealer("Dealer",[],0)                     # inicialize Dealer
    clear_output()
    game = Deck([])                                     # Inicialize Deck
    game.cards()                                        # Inicialize cards
    num_of_decks = int(input("Enter amount of decks: "))  # ask user how many decks user want to use in the game
    clear_output()
    game.deck_of_cards = game.deck_of_cards * num_of_decks # inicialize 1 big deck
    game.shuffle()                                          # shuffle cards in deck
    while True:
        answer = input("Do yo want to play? y/n")
        clear_output()
        if answer.lower() == "y":
            start()
        elif answer.lower() == "n":
            break
        else:
            print("Wrong input")




main()
# Out:
# Alex has a 0 points
# clubs 5
# clubs 5
# Dealer has a 50 points
# hearts 12
# hearts 2
# hearts 2
# hiden card

# %%
#Expected output based on the outcome of the game - Below is what should happen when the player wins

# #Dealer Bust
# =============================
# Player wins!
# ==============================
# Player hand: [('Hearts', 6), ('Diamonds', 2), ('Spades', 6), ('Diamonds', 3)]: 17
# Dealer hand: [('Spades', 5), ('Clubs', 5), ('Diamonds', 12)]: 22
